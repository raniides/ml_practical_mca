# %%
#2317
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
drybean = pd.read_csv('Dry_Bean_Dataset.csv')

# %%
drybean
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
drybean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
# ...

# %%
#Selecting relevent features/columns
features = drybean.drop(columns=['Class'])

# %%
features
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
#KMeans 
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters = 4)
label = kmeans.fit_predict(features)
print(label)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# [1 1 1 ... 1 1 1]

# %%
centroids = kmeans.cluster_centers_
print(centroids)

#label_0 = drybean[label == 0]
#label_1 = drybean[label == 1]
#label_2 = drybean[label == 2]
# Out:
# [[7.48909504e+04 1.06896657e+03 4.01776552e+02 2.39012753e+02
#   1.68976279e+00 7.97729338e-01 7.60933033e+04 3.08316492e+02
#   7.51562991e-01 9.84200864e-01 8.22582704e-01 7.69345712e-01
#   5.39870200e-03 1.17279448e-03 5.93476590e-01 9.92428606e-01]
#  [3.47272881e+04 6.89789681e+02 2.51589550e+02 1.75877548e+02
#   1.44092774e+00 7.00809148e-01 3.51252541e+04 2.09689296e+02
#   7.57125915e-01 9.88594271e-01 9.13327798e-01 8.35914280e-01
#   7.33426644e-03 2.21888827e-03 7.01083275e-01 9.97019410e-01]
#  [1.73708006e+05 1.58682284e+03 5.93746342e+02 3.74494358e+02
#   1.58663498e+00 7.71053829e-01 1.76040635e+05 4.69270023e+02
#   7.76670114e-01 9.86888965e-01 8.64297508e-01 7.92303935e-01
#   3.44074408e-03 8.42278487e-04 6.28664768e-01 9.91829684e-01]
#  [5.02522670e+04 8.62834530e+02 3.31195467e+02 1.95078842e+02
#   1.71434847e+00 7.88802248e-01 5.09215386e+04 2.52570231e+02
#   7.34965919e-01 9.87012849e-01 8.50545124e-01 7.69709285e-01
# ...

# %%
cols = drybean.columns

#plt.scatter(label_0[cols[5]], label_0[cols[2]], color = 'red')
#plt.scatter(label_1[cols[5]], label_1[cols[2]], color = 'black')
#plt.scatter(label_2[cols[5]], label_2[cols[2]], color = 'pink')

plt.scatter(drybean[cols[2]], drybean[cols[3]], c=kmeans.labels_.astype(float), s=50, alpha=1)
#plt.scatter(centroids[:,0], centroids[:,1], c= "red", s=50)

plt.xlabel(cols[2])
plt.ylabel(cols[3])

plt.title('Clustering of Dry Bean Dataset')
plt.show()

# %%
#KMeans with PCA
# Selecting relevant features/columns
features = drybean.drop(columns=['Class'])

# Scale the features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Apply PCA
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca_features = pca.fit_transform(scaled_features)

# Fit KMeans to the PCA-transformed features
kmeans = KMeans(n_clusters=4)
labels = kmeans.fit_predict(pca_features)

centroids= kmeans.cluster_centers_
print(centroids)

# Plot the clusters
plt.figure(figsize=(10, 6))

#plt.scatter(pca_features[label == 0, 0], pca_features[label == 0, 1], color='red', label='Cluster 0')
#plt.scatter(pca_features[label == 1, 0], pca_features[label == 1, 1], color='black', label='Cluster 1')
#plt.scatter(pca_features[label == 2, 0], pca_features[label == 2, 1], color='pink', label='Cluster 2')
#plt.scatter(pca_features[label == 3, 0], pca_features[label == 3, 1], color='yellow', label='Cluster 3')

plt.scatter(pca_features[:, 0], pca_features[:, 1], c=labels.astype(float), s=50, alpha=0.5)
plt.scatter(centroids[:,0], centroids[:,1], c= "red",marker="x", s=50)

#plt.scatter(centers[:,0], centers[:,1], marker="x", color='g')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('KMeans Clustering with PCA')
plt.legend()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [[ 7.74159397  5.64655961]
#  [-1.55673679 -0.59390554]
#  [ 2.58728949 -0.89986836]
#  [-3.39811939  2.18282131]]
