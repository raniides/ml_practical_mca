# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#[]={}:

# %%
dataset = pd.read_csv("Dry_Bean_Dataset.csv")

# %%
dataset
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
dataset.head(2)
# Out:
#     Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0  28395    610.291       208.178117       173.888747      1.197191
# 1  28734    638.018       200.524796       182.734419      1.097356
#
#    Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# 0      0.549812       28715     190.141097  0.763923  0.988856   0.958027
# 1      0.411785       29172     191.272751  0.783968  0.984986   0.887034
#
#    Compactness  ShapeFactor1  ShapeFactor2  ShapeFactor3  ShapeFactor4  Class
# 0     0.913358      0.007332      0.003147      0.834222      0.998724  SEKER
# 1     0.953861      0.006979      0.003564      0.909851      0.998430  SEKER

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13611 entries, 0 to 13610
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             13611 non-null  int64
#  1   Perimeter        13611 non-null  float64
#  2   MajorAxisLength  13611 non-null  float64
#  3   MinorAxisLength  13611 non-null  float64
#  4   AspectRation     13611 non-null  float64
#  5   Eccentricity     13611 non-null  float64
#  6   ConvexArea       13611 non-null  int64
#  7   EquivDiameter    13611 non-null  float64
#  8   Extent           13611 non-null  float64
#  9   Solidity         13611 non-null  float64
#  10  roundness        13611 non-null  float64
#  11  Compactness      13611 non-null  float64
#  12  ShapeFactor1     13611 non-null  float64
#  13  ShapeFactor2     13611 non-null  float64
#  14  ShapeFactor3     13611 non-null  float64
#  15  ShapeFactor4     13611 non-null  float64
# ...

# %%
dataset.describe()
# Out:
#                 Area     Perimeter  MajorAxisLength  MinorAxisLength  \
# count   13611.000000  13611.000000     13611.000000     13611.000000
# mean    53048.284549    855.283459       320.141867       202.270714
# std     29324.095717    214.289696        85.694186        44.970091
# min     20420.000000    524.736000       183.601165       122.512653
# 25%     36328.000000    703.523500       253.303633       175.848170
# 50%     44652.000000    794.941000       296.883367       192.431733
# 75%     61332.000000    977.213000       376.495012       217.031741
# max    254616.000000   1985.370000       738.860154       460.198497
#
#        AspectRation  Eccentricity     ConvexArea  EquivDiameter        Extent  \
# count  13611.000000  13611.000000   13611.000000   13611.000000  13611.000000
# mean       1.583242      0.750895   53768.200206     253.064220      0.749733
# std        0.246678      0.092002   29774.915817      59.177120      0.049086
# ...

# %%
l = dataset.columns
print(l)
# Out:
# Index(['Area', 'Perimeter', 'MajorAxisLength', 'MinorAxisLength',
#        'AspectRation', 'Eccentricity', 'ConvexArea', 'EquivDiameter', 'Extent',
#        'Solidity', 'roundness', 'Compactness', 'ShapeFactor1', 'ShapeFactor2',
#        'ShapeFactor3', 'ShapeFactor4', 'Class'],
#       dtype='object')

# %%
dataset['Class'].unique()
# Out:
# array(['SEKER', 'BARBUNYA', 'BOMBAY', 'CALI', 'HOROZ', 'SIRA', 'DERMASON'],
#       dtype=object)

# %%
dataset['Class']=dataset['Class'].map({'SEKER':1,'BARBUNYA':2,'BOMBAY':3,'CALI':4,'HOROZ':5,'SIRA':6,'DERMASON':7})
dataset['Class']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 13606    7
# 13607    7
# 13608    7
# 13609    7
# 13610    7
# Name: Class, Length: 13611, dtype: int64

# %%
dataset['Class'].unique()
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
#Splitting dataset into train and test split

# %%
X = dataset.drop('Class',axis=1)

# %%
y = dataset['Class']

# %%
corr = dataset.corr()
corr
# Out:
#                      Area  Perimeter  MajorAxisLength  MinorAxisLength  \
# Area             1.000000   0.966722         0.931834         0.951602
# Perimeter        0.966722   1.000000         0.977338         0.913179
# MajorAxisLength  0.931834   0.977338         1.000000         0.826052
# MinorAxisLength  0.951602   0.913179         0.826052         1.000000
# AspectRation     0.241735   0.385276         0.550335        -0.009161
# Eccentricity     0.267481   0.391066         0.541972         0.019574
# ConvexArea       0.999939   0.967689         0.932607         0.951339
# EquivDiameter    0.984968   0.991380         0.961733         0.948539
# Extent           0.054345  -0.021160        -0.078062         0.145957
# Solidity        -0.196585  -0.303970        -0.284302        -0.155831
# roundness       -0.357530  -0.547647        -0.596358        -0.210344
# Compactness     -0.268067  -0.406857        -0.568377        -0.015066
# ...

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
X
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 13606    7
# 13607    7
# 13608    7
# 13609    7
# 13610    7
# Name: Class, Length: 13611, dtype: int64

# %%
#train and test split and also feature scaling

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train.shape
# Out:
# (10888, 16)

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()

# %%
X_train=ss.fit_transform(X_train)

# %%
X_test=ss.transform(X_test)

# %%
X_train
# Out:
# array([[-0.67714645, -0.93673145, -1.14176304, ...,  2.19831546,
#          2.13809873,  0.72849194],
#        [-0.20924325, -0.08914847, -0.08074255, ..., -0.31788938,
#         -0.35054179, -0.26580916],
#        [ 1.00602139,  1.25194717,  1.40672732, ..., -1.26255633,
#         -1.0313532 , -1.81489971],
#        ...,
#        [-0.56691175, -0.65462718, -0.71853848, ...,  0.65807319,
#          0.50486138,  0.93456096],
#        [-0.78615859, -1.0429358 , -1.1280348 , ...,  1.63433173,
#          1.22034746,  0.70814179],
#        [-0.42061134, -0.42018389, -0.39110508, ...,  0.02220538,
#         -0.12775572, -1.58321621]])

# %%
X_test.shape
# Out:
# (2723, 16)

# %%
#Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg_r=LogisticRegression()
lg_r.fit(X_train,y_train)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred =lg_r.predict(X_test)
y_pred
# Out:
# array([4, 2, 1, ..., 7, 6, 2])

# %%
y_test
# Out:
# 4723     4
# 2041     2
# 363      1
# 4618     4
# 6058     5
#         ..
# 4517     4
# 729      1
# 10710    7
# 8932     6
# 3041     2
# Name: Class, Length: 2723, dtype: int64

# %%
from sklearn.metrics import confusion_matrix
cm =confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[386,   2,   0,   0,   0,   8,   6],
#        [  0, 255,   0,  11,   0,  10,   0],
#        [  0,   0,  93,   0,   0,   0,   0],
#        [  1,   6,   0, 323,   6,   2,   0],
#        [  0,   2,   0,   7, 358,   7,   2],
#        [ 11,   1,   0,   1,  13, 459,  43],
#        [ 14,   0,   0,   0,   2,  44, 650]])

# %%
from sklearn.metrics import accuracy_score
a =accuracy_score(y_test,y_pred)
a
# Out:
# 0.9269188395152406

# %%
#[]={}:
from sklearn.metrics import precision_score
p =precision_score(y_test,y_pred,average='macro')
p
# Out:
# 0.9396942600059527

# %%
from sklearn.metrics import recall_score
r =recall_score(y_test,y_pred,average='macro')
r
# Out:
# 0.9395245927668088

# %%
from sklearn.metrics import f1_score
f1 =f1_score(y_test,y_pred,average='macro')
f1
# Out:
# 0.9395305679225816
